# %% [markdown]
# ## Disposizione gamma di colori nello spazio RGB a seconda delle tonalità di pelle

# %%
from matplotlib import pyplot as plt

# %%
skin = plt.imread('skin/pelle8.jpg')
graph = plt.imread('skin/res8.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('skin/pelle9.jpg')
graph = plt.imread('skin/res9.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('skin/pelle32.jpg')
graph = plt.imread('skin/res32.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('skin/pelle19.jpg')
graph = plt.imread('skin/res19.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('skin/pelle21.jpg')
graph = plt.imread('skin/res21.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('nonskin/sweat8.jpg')
graph = plt.imread('nonskin/res8.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('nonskin/sweat12.jpg')
graph = plt.imread('nonskin/res12.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('nonskin/sweat22.jpg')
graph = plt.imread('nonskin/res22.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()

# %%
skin = plt.imread('nonskin/sweat25.jpg')
graph = plt.imread('nonskin/res25.jpg')

titles = ['Texture', 'Istogramma']
images = [skin, graph]
plt.figure(figsize=(25,9))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i], fontsize = 30)
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()
