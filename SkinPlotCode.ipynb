# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('skin/pelle9.jpg', cv2.IMREAD_COLOR)
blu = cv2.calcHist([img], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img], [1], None, [256], [0, 256])
verde = cv2.calcHist([img], [2], None, [256], [0, 256]) 
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


ch1 = cv2.mean(img)

plt.figure(1)
plt.imshow(img)

plt.figure(2)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('skin/res9.jpg')
plt.show()
# print('Valore medio R: ' + str(channels[2]))
# print('Valore medio G: ' + str(channels[1]))
# print('Valore medio B: ' + str(channels[0]))

# %%
img2 = cv2.imread('skin/pelle8.jpg', cv2.IMREAD_COLOR)
blu = cv2.calcHist([img2], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img2], [1], None, [256], [0, 256])
verde = cv2.calcHist([img2], [2], None, [256], [0, 256]) 
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)


ch2 = cv2.mean(img2)

plt.figure(2)
plt.imshow(img2)

plt.figure(3)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('skin/res8.jpg')
plt.show()
# print('Valore medio R: ' + str(channels[2]))
# print('Valore medio G: ' + str(channels[1]))
# print('Valore medio B: ' + str(channels[0]))

# %%
img3 = cv2.imread('skin/pelle21.jpg', cv2.IMREAD_COLOR)
blu = cv2.calcHist([img3], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img3], [1], None, [256], [0, 256])
verde = cv2.calcHist([img3], [2], None, [256], [0, 256]) 
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)


ch3 = cv2.mean(img3)
plt.figure(4)
plt.imshow(img3)

plt.figure(5)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('skin/res21.jpg')
plt.show()
# print('Valore medio R: ' + str(channels[2]))
# print('Valore medio G: ' + str(channels[1]))
# print('Valore medio B: ' + str(channels[0]))

# %%
img4 = cv2.imread('skin/pelle19.jpg', cv2.IMREAD_COLOR)
blu = cv2.calcHist([img4], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img4], [1], None, [256], [0, 256])
verde = cv2.calcHist([img4], [2], None, [256], [0, 256]) 
img4 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)


ch4 = cv2.mean(img4)
plt.figure(6)
plt.imshow(img4)

plt.figure(7)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('skin/res19.jpg')
plt.show()
# print('Valore medio R: ' + str(channels[2]))
# print('Valore medio G: ' + str(channels[1]))
# print('Valore medio B: ' + str(channels[0]))

# %%
img5 = cv2.imread('skin/pelle32.jpg', cv2.IMREAD_COLOR)
blu = cv2.calcHist([img5], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img5], [1], None, [256], [0, 256])
verde = cv2.calcHist([img5], [2], None, [256], [0, 256]) 
img5 = cv2.cvtColor(img5, cv2.COLOR_BGR2RGB)


ch5 = cv2.mean(img5)
plt.figure(8)
plt.imshow(img5)

plt.figure(9)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('skin/res32.jpg')
plt.show()
# print('Valore medio R: ' + str(channels[2]))
# print('Valore medio G: ' + str(channels[1]))
# print('Valore medio B: ' + str(channels[0]))

# %%
chp_r = np.array([ch1[2], ch2[2], ch3[2], ch4[2], ch5[2]])
chp_g = np.array([ch1[1], ch2[1], ch3[1], ch4[1], ch5[1]])
chp_b = np.array([ch1[0], ch2[0], ch3[0], ch4[0], ch5[0]])

plt.figure(figsize=(10, 5))
plt.title('Valori medi dei canali RGB | Pelle',fontsize=12)
plt.plot(chp_b, "-b", label = "blu")
plt.plot(chp_g, "-g", label = "verde")
plt.plot(chp_r, "-r", label = "rosso")
plt.legend(loc = 'upper left')
# plt.plot(chp_r, color = 'r')
# plt.plot(chp_g, color = 'g')
# plt.plot(chp_b, color = 'b')
plt.savefig("images/grafop.jpg")
plt.show()

# %%
img6 = cv2.imread('nonskin/sweat22.jpg')
blu = cv2.calcHist([img6], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img6], [1], None, [256], [0, 256])
verde = cv2.calcHist([img6], [2], None, [256], [0, 256]) 
img6 = cv2.cvtColor(img6, cv2.COLOR_BGR2RGB)


ch6 = cv2.mean(img6)
plt.figure(10)
plt.imshow(img6)

plt.figure(11)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('nonskin/res22.jpg')
plt.show()

# %%
img7 = cv2.imread('nonskin/sweat12.jpg')
blu = cv2.calcHist([img7], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img7], [1], None, [256], [0, 256])
verde = cv2.calcHist([img7], [2], None, [256], [0, 256]) 
img7 = cv2.cvtColor(img7, cv2.COLOR_BGR2RGB)


ch7 = cv2.mean(img7)
plt.figure(12)
plt.imshow(img7)

plt.figure(13)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('nonskin/res12.jpg')
plt.show()

# %%
img8 = cv2.imread('nonskin/sweat8.jpg')
blu = cv2.calcHist([img8], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img8], [1], None, [256], [0, 256])
verde = cv2.calcHist([img8], [2], None, [256], [0, 256]) 
img8 = cv2.cvtColor(img8, cv2.COLOR_BGR2RGB)


ch8 = cv2.mean(img8)
plt.figure(14)
plt.imshow(img8)

plt.figure(15)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('nonskin/res8.jpg')
plt.show()

# %%
img9 = cv2.imread('nonskin/sweat25.jpg')
blu = cv2.calcHist([img9], [0], None, [256], [0, 256])
rosso = cv2.calcHist([img9], [1], None, [256], [0, 256])
verde = cv2.calcHist([img9], [2], None, [256], [0, 256]) 
img9 = cv2.cvtColor(img9, cv2.COLOR_BGR2RGB)


ch9 = cv2.mean(img9)
plt.figure(16)
plt.imshow(img9)

plt.figure(17)
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
plt.title("Istogramma di tutti i colori")
plt.hist(blu,color="darkblue")
plt.hist(verde,color="green")
plt.hist(rosso,color="red")
plt.xlabel('Quantità di pixel')
plt.ylabel('Canale')
 
plt.subplot(2,1,2)
plt.title("Grafico di tutti i colori")
plt.plot(blu, "-b", label = "blu")
plt.plot(verde, "-g", label = "verde")
plt.plot(rosso, "-r", label = "rosso")
plt.legend(loc = 'upper left')
plt.ylabel('Quantità di pixel')
plt.xlabel('Canale')
 
plt.tight_layout()
plt.savefig('nonskin/res25.jpg')
plt.show()

# %%
chnp_r = np.array([ch6[2], ch7[2], ch8[2], ch9[2]])
chnp_g = np.array([ch6[1], ch7[1], ch8[1], ch9[1]])
chnp_b = np.array([ch6[0], ch7[0], ch8[0], ch9[0]])

plt.figure(figsize=(10, 5))
plt.title('Valori medi dei canali RGB | Non - Pelle',fontsize=12)
plt.plot(chnp_b, "-b", label = "blu")
plt.plot(chnp_g, "-g", label = "verde")
plt.plot(chnp_r, "-r", label = "rosso")
plt.legend(loc = 'upper left')
# plt.plot(chp_r, color = 'r')
# plt.plot(chp_g, color = 'g')
# plt.plot(chp_b, color = 'b')
plt.savefig("images/grafonp.jpg")
plt.show()

# %%
im = cv2.imread('images/grafop.jpg')
im2 = cv2.imread('images/grafonp.jpg')

images = [im, im2]
plt.figure(figsize=(20,10))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i],'gray')
    plt.xticks([]),plt.yticks([])
plt.tight_layout()
plt.show()
